# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Set-Up

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %% [markdown]
# ## Data Generator

# %%
# Out:
# array([-1.        , -0.95918367, -0.91836735, -0.87755102, -0.83673469,
#        -0.79591837, -0.75510204, -0.71428571, -0.67346939, -0.63265306,
#        -0.59183673, -0.55102041, -0.51020408, -0.46938776, -0.42857143,
#        -0.3877551 , -0.34693878, -0.30612245, -0.26530612, -0.2244898 ,
#        -0.18367347, -0.14285714, -0.10204082, -0.06122449, -0.02040816,
#         0.02040816,  0.06122449,  0.10204082,  0.14285714,  0.18367347,
#         0.2244898 ,  0.26530612,  0.30612245,  0.34693878,  0.3877551 ,
#         0.42857143,  0.46938776,  0.51020408,  0.55102041,  0.59183673,
#         0.63265306,  0.67346939,  0.71428571,  0.75510204,  0.79591837,
#         0.83673469,  0.87755102,  0.91836735,  0.95918367,  1.        ])

# %%
def sig(x):
    return 1 / (1 + np.exp(-x))

x = np.linspace(-2, 2, 100)
y1 = x
y2 = x + 1
y3 = 2*x

y4 = 2*x - 1

l1 = sig(y1)
l2 = sig(y2)
l3 = sig(y3)
l4 = sig(y4)

# %%
fig, ax = plt.subplots()
ax.plot(x, y1)
# ax.plot(x, y2)
# ax.plot(x, y3)
# ax.plot(x, y4)
ax.plot(x, l1)
ax.hlines(0, xmin=min(x), xmax=max(x), linestyles='dashed', color='#ff7f0e')
ax.hlines(0.5, xmin=min(x), xmax=max(x), linestyles='dashed', color='#ff7f0e')
ax.hlines(1, xmin=min(x), xmax=max(x), linestyles='dashed', color='#ff7f0e')
# ax.vlines(0, ymin=min(y1), ymax=max(y1), linestyles='dashed', color='black')
# ax.hlines(0, xmin=min(x), xmax=max(x), linestyles='dashed', color='black')

ax.set_xlim(-1,1)
ax.set_ylim(-.1,1.1)
plt.show()
